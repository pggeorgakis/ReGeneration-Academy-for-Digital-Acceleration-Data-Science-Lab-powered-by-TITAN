# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1= pd.read_hdf("model2.h5")

# %%
train_perc = 0.8
test_split = 0.2
 
train_split = int(len(data1) * train_perc)
train_data = data1[:train_split]
test_split = int(len(data1) * test_split)
test_data = data1[train_split:(train_split+test_split+1)]

# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
from scipy import stats
fan= train_data["main_fan_speed_rpm_pv"]
a=np.mean(fan)
b=np.std(fan)
qqplot(fan , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(fan)
plt.grid()

# %%
train_data['main_fan_speed_rpm_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean         909.881998
# std          325.909498
# min           75.000000
# 50%          928.200000
# 90%          986.600000
# 95%          999.600000
# 97%         1011.500000
# 98%         1023.400000
# 99%         1054.035600
# 99.5%       1086.387800
# 99.7%       1125.957560
# 99.8%       1153.023040
# 99.9%       1190.000000
# 99.95%     11507.909160
# 99.96%     11629.237152
# 99.97%     11666.627964
# 99.98%     11716.373128
# 99.99%     11818.900708
# max        12009.810000
# Name: main_fan_speed_rpm_pv, dtype: float64

# %%
stats.kstest(fan , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(fan), stats.kurtosis(fan)
# Out:
# (29.210110435470767, 959.523763155577)

# %%
mill = train_data["mill_dp_mbar_pv"]
a=np.mean(mill)
b=np.std(mill)
qqplot(mill , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(mill)

# %%
train_data['mill_dp_mbar_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean          35.068852
# std            3.257810
# min            1.110000
# 50%           34.830000
# 90%           38.890000
# 95%           40.210000
# 97%           41.390000
# 98%           42.540000
# 99%           44.560000
# 99.5%         46.960000
# 99.7%         48.610000
# 99.8%         49.707360
# 99.9%         52.058680
# 99.95%        54.613900
# 99.96%        55.604944
# 99.97%        57.619284
# 99.98%        59.414944
# 99.99%        61.475384
# max           65.930000
# Name: mill_dp_mbar_pv, dtype: float64

# %%
stats.kstest(mill , "norm")
# Out:
# KstestResult(statistic=0.9999668972703197, pvalue=0.0)

# %%
stats.skew(mill), stats.kurtosis(mill)
# Out:
# (0.6136443818038417, 4.405257406761715)

# %%
ss = train_data["separator_speed_rpm_pv"]
a=np.mean(ss)
b=np.std(ss)
qqplot(ss , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(ss)
plt.grid()

# %%
train_data['separator_speed_rpm_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean         763.417285
# std           55.828968
# min           21.070000
# 50%          769.210000
# 90%          812.780000
# 95%          823.810000
# 97%          830.690000
# 98%          836.600000
# 99%          840.560000
# 99.5%        989.020000
# 99.7%       1042.470000
# 99.8%       1043.680000
# 99.9%       1044.310000
# 99.95%      1045.950000
# 99.96%      1046.000000
# 99.97%      1046.160000
# 99.98%      1046.320000
# 99.99%      1046.530000
# max         1690.000000
# Name: separator_speed_rpm_pv, dtype: float64

# %%
stats.kstest(ss , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(ss), stats.kurtosis(ss)
# Out:
# (-1.375083119907101, 10.291543473801848)

# %%
grind = train_data["grinding_pressure_bar_pv"]
a=np.mean(grind)
b=np.std(grind)
qqplot(grind , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(grind)
plt.grid()

# %%
train_data['grinding_pressure_bar_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean         117.305813
# std            6.596539
# min           36.000000
# 50%          118.000000
# 90%          122.000000
# 95%          122.000000
# 97%          123.000000
# 98%          123.000000
# 99%          123.000000
# 99.5%        123.000000
# 99.7%        124.000000
# 99.8%        124.000000
# 99.9%        124.000000
# 99.95%       124.000000
# 99.96%       125.000000
# 99.97%       125.000000
# 99.98%       125.000000
# 99.99%       125.000000
# max          126.000000
# Name: grinding_pressure_bar_pv, dtype: float64

# %%
stats.kstest(grind , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(grind), stats.kurtosis(grind)
# Out:
# (-5.0806758115950705, 32.16214654267397)

# %%
bucket = train_data["bucket_elv_mtr_pwr_kw_pv"]
a=np.mean(bucket)
b=np.std(bucket)
qqplot(bucket , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(bucket)
plt.grid()

# %%
train_data['bucket_elv_mtr_pwr_kw_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean           4.862349
# std            0.180220
# min            0.000000
# 50%            4.850000
# 90%            5.040000
# 95%            5.100000
# 97%            5.140000
# 98%            5.180000
# 99%            5.300000
# 99.5%          5.500000
# 99.7%          5.680000
# 99.8%          5.859120
# 99.9%          6.239560
# 99.95%         6.704340
# 99.96%         6.881648
# 99.97%         7.106868
# 99.98%         7.505824
# 99.99%         8.076868
# max           10.360000
# Name: bucket_elv_mtr_pwr_kw_pv, dtype: float64

# %%
stats.kstest(bucket , "norm")
# Out:
# KstestResult(statistic=0.9997295107250931, pvalue=0.0)

# %%
stats.skew(bucket), stats.kurtosis(bucket)
# Out:
# (-1.4679843953863094, 148.98845512513932)

# %%
ash1 = train_data["fly_ash_1_ton_h_pv"]
a=np.mean(ash1)
b=np.std(ash1)
qqplot(ash1 , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(ash1)
plt.grid()

# %%
train_data['fly_ash_1_ton_h_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean           0.945458
# std            4.388459
# min            0.000000
# 50%            0.010000
# 90%            0.050000
# 95%            0.100000
# 97%           21.230000
# 98%           22.480000
# 99%           24.020000
# 99.5%         24.480000
# 99.7%         24.680000
# 99.8%         24.809120
# 99.9%         24.970000
# 99.95%        25.120000
# 99.96%        25.160000
# 99.97%        25.223736
# 99.98%        25.360000
# 99.99%        25.688956
# max           28.780000
# Name: fly_ash_1_ton_h_pv, dtype: float64

# %%
stats.kstest(ash1 , "norm")
# Out:
# KstestResult(statistic=0.5, pvalue=0.0)

# %%
stats.skew(ash1), stats.kurtosis(ash1)
# Out:
# (4.652203081939339, 20.058363005432337)

# %%
ash2 = train_data["fly_ash_2_ton_h_pv"]
a=np.mean(ash2)
b=np.std(ash2)
qqplot(ash2 , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(ash2)
plt.grid()

# %%
train_data['fly_ash_2_ton_h_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean           0.804580
# std            3.904152
# min            0.000000
# 50%            0.080000
# 90%            0.110000
# 95%            0.140000
# 97%           15.600000
# 98%           22.190000
# 99%           23.550000
# 99.5%         24.140000
# 99.7%         24.410000
# 99.8%         24.569120
# 99.9%         24.740000
# 99.95%        24.890000
# 99.96%        24.930000
# 99.97%        24.980000
# 99.98%        25.010000
# 99.99%        25.130000
# max           27.120000
# Name: fly_ash_2_ton_h_pv, dtype: float64

# %%
stats.kstest(ash2 , "norm")
# Out:
# KstestResult(statistic=0.5, pvalue=0.0)

# %%
stats.skew(ash2), stats.kurtosis(ash2)
# Out:
# (5.317449520950313, 26.763529284296133)

# %%
feed = train_data["total_feed_ton_h_pv"]
a=np.mean(feed)
b=np.std(feed)
qqplot(feed , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(feed)
plt.grid()

# %%
train_data['total_feed_ton_h_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean          63.969030
# std            7.850501
# min           40.010000
# 50%           64.080000
# 90%           73.170000
# 95%           76.360000
# 97%           77.720000
# 98%           78.520000
# 99%           79.330000
# 99.5%         79.717800
# 99.7%         79.850000
# 99.8%         79.900000
# 99.9%         79.950000
# 99.95%        79.980000
# 99.96%        79.980000
# 99.97%        79.980000
# 99.98%        79.980000
# 99.99%        79.990000
# max           79.990000
# Name: total_feed_ton_h_pv, dtype: float64

# %%
stats.kstest(feed , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(feed), stats.kurtosis(feed)
# Out:
# (-0.2570661565266873, -0.48254803543080715)

# %%
water = train_data["mill_injection_water_m3_h_pv"]
a=np.mean(water)
b=np.std(water)
qqplot(water , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
sns.distplot(water)
plt.grid()

# %%
train_data['mill_injection_water_m3_h_pv'].describe(percentiles=[.90, .95, .97, .98, .99, .995, .997, .998, .999, .9995, .9996, .9997, .9998, .9999])
# Out:
# count     151045.000000
# mean           1.856808
# std            0.764408
# min            0.000000
# 50%            1.960000
# 90%            2.700000
# 95%            2.840000
# 97%            2.850000
# 98%            2.850000
# 99%            2.860000
# 99.5%          2.860000
# 99.7%          2.870000
# 99.8%          2.870000
# 99.9%          2.880000
# 99.95%         2.880000
# 99.96%         2.880000
# 99.97%         2.880000
# 99.98%         2.880000
# 99.99%         2.890000
# max            2.920000
# Name: mill_injection_water_m3_h_pv, dtype: float64

# %%
stats.kstest(water , "norm")
# Out:
# KstestResult(statistic=0.7060203135344245, pvalue=0.0)

# %%
stats.skew(water), stats.kurtosis(water)
# Out:
# (-0.6449329081154301, -0.40413962584547614)

# %% [markdown]
# using the filter that was created from the above analysis

# %%
mask2 = (train_data['main_fan_speed_rpm_pv']>550) & (train_data['main_fan_speed_rpm_pv']<1100) & (train_data['separator_speed_rpm_pv']>650) & (train_data['separator_speed_rpm_pv']<850) & (train_data['grinding_pressure_bar_pv']>110) & (train_data['grinding_pressure_bar_pv']< 123) & (train_data['bucket_elv_mtr_pwr_kw_pv']>4.5) & (train_data['bucket_elv_mtr_pwr_kw_pv']<5.25) &(train_data["mill_dp_mbar_pv"]>25)& (train_data["mill_dp_mbar_pv"]<45)
train_data = train_data[mask2].reset_index(drop=True)

# %%
fan= train_data["main_fan_speed_rpm_pv"]
a=np.mean(fan)
b=np.std(fan)
qqplot(fan , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(fan, "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(fan) , stats.kurtosis(fan)
# Out:
# (-0.8575823493873589, 0.47187820547440085)

# %%
mill = train_data["mill_dp_mbar_pv"]
a=np.mean(mill)
b=np.std(mill)
qqplot(mill , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(mill , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(mill), stats.kurtosis(mill)
# Out:
# (0.21848585357502406, 0.07223198458883573)

# %%
ss = train_data["separator_speed_rpm_pv"]
a=np.mean(ss)
b=np.std(ss)
qqplot(ss , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(ss , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(ss), stats.kurtosis(ss)
# Out:
# (-0.4147325155238724, 0.2765170767484606)

# %%
grind = train_data["grinding_pressure_bar_pv"]
a=np.mean(grind)
b=np.std(grind)
qqplot(grind , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(grind , "norm")
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
stats.skew(grind), stats.kurtosis(grind)
# Out:
# (-0.25713334104847957, -0.23426591152085585)

# %%
bucket = train_data["bucket_elv_mtr_pwr_kw_pv"]
a=np.mean(bucket)
b=np.std(bucket)
qqplot(bucket , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(bucket , "norm")
# Out:
# KstestResult(statistic=0.9999967586187126, pvalue=0.0)

# %%
stats.skew(bucket), stats.kurtosis(bucket)
# Out:
# (0.12725106182108464, -0.21375737419427576)

# %%
ash1 = train_data["fly_ash_1_ton_h_pv"]
a=np.mean(ash1)
b=np.std(ash1)
qqplot(ash1 , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(ash1 , "norm")
# Out:
# KstestResult(statistic=0.5, pvalue=0.0)

# %%
stats.skew(ash1), stats.kurtosis(ash1)
# Out:
# (4.492428665999783, 18.555190082880905)

# %%
ash2 = train_data["fly_ash_2_ton_h_pv"]
a=np.mean(ash2)
b=np.std(ash2)
qqplot(ash2 , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(ash2 , "norm")
# Out:
# KstestResult(statistic=0.5, pvalue=0.0)

# %%
stats.skew(ash2), stats.kurtosis(ash2)
# Out:
# (5.095162564268293, 24.398034232381615)

# %%
feed = train_data["total_feed_ton_h_pv"]
a=np.mean(feed)
b=np.std(feed)
qqplot(feed , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(ash2 , "norm")
# Out:
# KstestResult(statistic=0.5, pvalue=0.0)

# %%
stats.skew(ash2), stats.kurtosis(ash2)
# Out:
# (5.095162564268293, 24.398034232381615)

# %%
water = train_data["mill_injection_water_m3_h_pv"]
a=np.mean(water)
b=np.std(water)
qqplot(water , loc = a, scale = b)
plt.grid()
pyplot.show()

# %%
stats.kstest(water , "norm")
# Out:
# KstestResult(statistic=0.7333383366772659, pvalue=0.0)

# %%
stats.skew(water), stats.kurtosis(water)
# Out:
# (-0.6485017594128422, -0.33541762940838016)

# %% [markdown]
# # Interpolation

# %%
mask2 = (train_data['main_fan_speed_rpm_pv']>550) & (train_data['main_fan_speed_rpm_pv']<1100) & (train_data['separator_speed_rpm_pv']>650) & (train_data['separator_speed_rpm_pv']<850) & (train_data['grinding_pressure_bar_pv']>110) & (train_data['grinding_pressure_bar_pv']< 123) & (train_data['bucket_elv_mtr_pwr_kw_pv']>4.5) & (train_data['bucket_elv_mtr_pwr_kw_pv']<5.25) &(train_data["mill_dp_mbar_pv"]>25)& (train_data["mill_dp_mbar_pv"]<45)
train_data = train_data[mask2].reset_index(drop=True)

# %%
train_data.drop(["mill_motor_pwr_kw_pv", "mill_operation"], axis = 1, inplace =True)

# %%
train_data['date'] = pd.to_datetime(train_data['date'], dayfirst=True)
train_data['date'] = train_data['date'].apply(lambda x: x.replace(second=0))
train_data = train_data.groupby(train_data['date']).mean()

# %%
train_data.describe()
# Out:
#        total_feed_ton_h_pv  fly_ash_1_ton_h_pv  fly_ash_2_ton_h_pv  \
# count         67181.000000        67181.000000        67181.000000
# mean             64.706609            1.095594            0.924747
# std               7.669520            4.713189            4.193247
# min              40.010000            0.000000            0.000000
# 25%              59.985000            0.010000            0.065000
# 50%              65.075000            0.015000            0.075000
# 75%              70.725000            0.025000            0.090000
# max              79.990000           28.780000           25.635000
#
#        main_fan_speed_rpm_pv  separator_speed_rpm_pv  \
# count           67181.000000            67181.000000
# mean              903.669710              770.334637
# std                77.181196               34.080814
# min               595.160000              650.020000
# 25%               845.065000              751.125000
# ...

# %%
train_datal=train_data.asfreq("1T")
train_datal=train_datal.interpolate(method='linear', axis=0, limit=None, inplace=False, limit_direction='backward', limit_area="inside")
train_datal.describe()
# Out:
#        total_feed_ton_h_pv  fly_ash_1_ton_h_pv  fly_ash_2_ton_h_pv  \
# count        204817.000000       204817.000000       204817.000000
# mean             64.935408            2.644713            2.096118
# std               8.480172            5.808577            5.132087
# min              40.010000            0.000000            0.000000
# 25%              58.391273            0.010000            0.068580
# 50%              65.754104            0.020000            0.081492
# 75%              71.339302            0.919547            0.111350
# max              79.990000           28.780000           25.635000
#
#        main_fan_speed_rpm_pv  separator_speed_rpm_pv  \
# count          204817.000000           204817.000000
# mean              907.265939              741.251538
# std                72.886459               38.593261
# min               595.160000              650.020000
# 25%               862.263871              712.310000
# ...

# %%
train_dataq=train_data.asfreq("1T")
train_dataq=train_dataq.interpolate(method='quadratic', axis=0, limit=None, inplace=False, limit_direction='backward', limit_area="inside")
train_dataq.describe()

# %%
train_datac=train_data.asfreq("1T")
train_datac=train_datac.interpolate(method='cubic', axis=0, limit=None, inplace=False, limit_direction='backward', limit_area="inside")
train_datac.describe()
# Out:
#        fly_ash_1_ton_h_pv  fly_ash_2_ton_h_pv  main_fan_speed_rpm_pv  \
# count       204817.000000       204817.000000          204817.000000
# mean            -8.469798          -10.665866             883.573754
# std            538.597865          182.661574            1013.432989
# min          -6171.319766        -2047.032451           -8420.620893
# 25%              0.000000            0.020000             850.626548
# 50%              0.025000            0.085000             940.100000
# 75%             12.020982            4.576116             963.712422
# max           2089.593856         1066.832053            9346.674512
#
#        separator_speed_rpm_pv  grinding_pressure_bar_pv  \
# count           204817.000000             204817.000000
# mean              -253.188807                 54.060197
# std               4442.927316                829.396189
# min             -29941.110051              -6123.069345
# 25%                692.265000                 97.077296
# ...

# %%
train_datap=train_data.asfreq("1T")
train_datap=train_datap.interpolate(method='polynomial',order=5, axis=0, limit=None, inplace=False, limit_direction='backward', limit_area="inside")
train_datap.describe()
# Out:
#        fly_ash_1_ton_h_pv  fly_ash_2_ton_h_pv  main_fan_speed_rpm_pv  \
# count        2.048170e+05        2.048170e+05           2.048170e+05
# mean         8.734941e+04       -1.003374e+05           4.327602e+04
# std          5.448355e+05        6.394879e+05           3.684154e+05
# min         -6.834856e+05       -5.607727e+06          -6.959895e+05
# 25%          0.000000e+00       -9.896812e-02           8.542250e+02
# 50%          3.000000e-02        8.500000e-02           9.404640e+02
# 75%          4.089504e+02        1.333083e+02           9.758000e+02
# max          4.769740e+06        2.092552e+05           4.408216e+06
#
#        separator_speed_rpm_pv  grinding_pressure_bar_pv  \
# count            2.048170e+05              2.048170e+05
# mean            -7.838326e+05             -3.776184e+04
# std              3.891355e+06              1.412321e+06
# min             -2.834139e+07             -1.225999e+07
# 25%              2.556999e+02             -4.334470e+01
# ...
